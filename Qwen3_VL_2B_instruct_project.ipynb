# %% [markdown]
# #### Setup

# %%
# !nvidia-smi
# Out:
# Thu May 28 21:06:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   27C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -q git+https://github.com/huggingface/transformers
# !pip install -q accelerate pillow
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done

# %%
import torch
from transformers import Qwen3VLForConditionalGeneration, AutoProcessor

MODEL_ID = "Qwen/Qwen3-VL-2B-Instruct"

model = Qwen3VLForConditionalGeneration.from_pretrained(
    MODEL_ID,
    dtype=torch.bfloat16,
    device_map="auto",
)
processor = AutoProcessor.from_pretrained(MODEL_ID)
# Out:
# config.json:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.26G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/625 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/269 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/390 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/5.50k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/10.9k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# video_preprocessor_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]

# %%
from PIL import Image
from IPython.display import display

DISPLAY_MAX_SIZE = 300


def _show(img_or_path):
    """Display an image at a readable notebook size without changing the original."""
    img = Image.open(img_or_path) if isinstance(img_or_path, str) else img_or_path
    preview = img.copy()
    preview.thumbnail((DISPLAY_MAX_SIZE, DISPLAY_MAX_SIZE))
    display(preview)

# %% [markdown]
# #### Dataset

# %%
###  Do not need to rerun this unless the runtime restarted. ###

from datasets import load_dataset
from itertools import islice

DATASET_ID = "Supermaxman/esa-hubble"

# Load dataset as streaming dataset.
dataset_stream = load_dataset(DATASET_ID, split="train", streaming=True)

# Choose how many rows/images you want to inspect.
N = 266

rows = list(islice(dataset_stream, N))

print("Loaded rows:", len(rows))
print("Available columns:")
print(rows[0].keys())
# Out:
# README.md:   0%|          | 0.00/14.8k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/200 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (91414305 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (97257819 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (93708021 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (98892662 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (104260827 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (96000800 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Loaded rows: 266
# Available columns:
# dict_keys(['image', 'text', 'id', 'title', 'description', 'credits', 'url', 'Id', 'Type', 'Release date', 'Related releases', 'Size', 'Name', 'Distance', 'Constellation', 'Category', 'Position (RA)', 'Position (Dec)', 'Field of view', 'Orientation', 'width', 'height', 'file_size', 'crop_w', 'crop_h', 'cropped', 'Related science announcements', 'Related announcements'])

# %% [markdown]
# #### Project Reference Files
#
# The AVM reference text and true AVM labels are loaded from the project GitHub repo, so they do not need to be embedded in this notebook.

# %%
import urllib.request

PROJECT_RAW_BASE_URL = "https://raw.githubusercontent.com/QihanQG/ECS-189G-final-project/main"
AVM_REFERENCE_URL = f"{PROJECT_RAW_BASE_URL}/AVM_Reference"
TRUE_AVM_CODES_URL = f"{PROJECT_RAW_BASE_URL}/TRUE_AVM_CODES"


def load_text_from_url(url):
    """Load a UTF-8 text file from a public URL."""
    with urllib.request.urlopen(url, timeout=30) as response:
        return response.read().decode("utf-8")


def parse_true_avm_codes(text):
    """Parse lines like `12: C.5.1.1, C.5.4.6` into a list of code lists."""
    labels_by_row = {}

    for line in text.splitlines():
        line = line.strip()
        if not line or ":" not in line:
            continue

        row_text, codes_text = line.split(":", 1)
        row_index = int(row_text.strip())
        codes = [code.strip() for code in codes_text.split(",") if code.strip()]
        labels_by_row[row_index] = codes

    expected_indices = list(range(len(labels_by_row)))
    actual_indices = sorted(labels_by_row)
    if actual_indices != expected_indices:
        raise ValueError("TRUE_AVM_CODES rows are missing or out of order.")

    return [labels_by_row[i] for i in expected_indices]


avm_reference_text = load_text_from_url(AVM_REFERENCE_URL)
TRUE_AVM_CODES = parse_true_avm_codes(load_text_from_url(TRUE_AVM_CODES_URL))


# Example
print(f"Loaded AVM reference text: {len(avm_reference_text):,} characters")
print(f"Loaded AVM ground-truth labels: {len(TRUE_AVM_CODES)} rows")
print("Row 0 true AVM code(s):", TRUE_AVM_CODES[0])
# Out:
# Loaded AVM reference text: 7,092 characters
# Loaded AVM ground-truth labels: 266 rows
# Row 0 true AVM code(s): ['B.3.6.4.1', 'B.4.1.3']

# %% [markdown]
# #### Chat

# %% [markdown]
# # Chat with the actual dataset

# %%
def ask_qwen_restricted(image, prompt, system_prompt="", max_new_tokens=256):
    """
    Ask Qwen a question with a domain-restricting system prompt.
    """
    if isinstance(image, str):
        img = Image.open(image).convert("RGB")
    else:
        img = image.convert("RGB") if isinstance(image, Image.Image) else Image.fromarray(image).convert("RGB")

    _show(img)

    # Initialize messages list
    messages = []

    # Add system prompt if provided to restrict the domain
    if system_prompt:
        messages.append({
            "role": "system",
            "content": [{"type": "text", "text": system_prompt}]
        })

    # Add the user prompt with the image
    messages.append({
        "role": "user",
        "content": [
            {"type": "image", "image": img},
            {"type": "text", "text": prompt},
        ],
    })

    inputs = processor.apply_chat_template(
        messages, tokenize=True, add_generation_prompt=True,
        return_dict=True, return_tensors="pt",
    ).to(model.device)

    with torch.no_grad():
        out_ids = model.generate(**inputs, max_new_tokens=max_new_tokens)

    trimmed = [o[len(i):] for i, o in zip(inputs.input_ids, out_ids)]
    reply = processor.batch_decode(trimmed, skip_special_tokens=True)[0]

    print(reply)
    return reply

# %% [markdown]
# #### The Prompt:

# %%
avm_task_instructions = """
You are an expert astronomical image classifier. Given an astronomical image, your task is to identify the type(s) of object(s) or phenomenon(a) depicted and express each as an AVM 1.1 code.

AVM 1.1 Code Format:
Each code has the form <Scale>.<Taxonomy>, where:

Scale (single letter prefix):
A = Solar System
B = Milky Way
C = Local Universe
D = Early Universe
E = Unspecified
Taxonomy (dot-separated numbers following the scale letter), e.g.:
B.4.1.3 -> Milky Way : Nebula : Type : Planetary
C.5.1.1 -> Local Universe : Galaxy : Type : Spiral
D.5.5.3 -> Early Universe : Galaxy : Grouping : Cluster
Instructions:

Carefully examine the image and identify all astronomical object types or phenomena present.
For each identified type, select the most specific matching AVM 1.1 code.
An image may contain more than one type â€” if so, provide one code per type, separated by commas.
Output only the AVM code(s), nothing else. No explanations, no labels, no extra text.
Output format:

Single type: B.4.1.3
Multiple types: C.5.1.1, C.5.1.2
"""

avm_system_prompt = avm_reference_text + "\n\n" + avm_task_instructions

# %% [markdown]
# #### Batch Prediction Output
#
#  Run Qwen on every loaded dataset image and save predictions as `index: AVM_CODE, AVM_CODE` lines.

# %%
import re
from pathlib import Path

# Change this if you want to use different prompt for qwen prediction so that it doesn't overwrite the existing saved files.
PROMPT_RUN_NAME = "strict_codes_v1"
PREDICTIONS_OUTPUT_PATH = Path(f"qwen_predicted_avm_codes_{PROMPT_RUN_NAME}.txt")
AVM_CODE_PATTERN = re.compile(r"\b[A-EX]\.\d+(?:\.\d+)*\b")

NUM_SAMPLES_TO_RUN = 266


def ask_qwen_avm_codes_no_display(image, system_prompt, max_new_tokens= 100):
    """Ask Qwen for AVM code predictions without displaying the image."""
    if isinstance(image, str):
        img = Image.open(image).convert("RGB")
    else:
        img = image.convert("RGB") if isinstance(image, Image.Image) else Image.fromarray(image).convert("RGB")

    messages = [
        {
            "role": "system",
            "content": [{"type": "text", "text": system_prompt}],
        },
        {
            "role": "user",
            "content": [
                {"type": "image", "image": img},
                {"type": "text", "text": "Return only the AVM code or codes for this image."},
            ],
        },
    ]

    inputs = processor.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_dict=True,
        return_tensors="pt",
    ).to(model.device)

    with torch.no_grad():
        out_ids = model.generate(**inputs, max_new_tokens=max_new_tokens)

    trimmed = [o[len(i):] for i, o in zip(inputs.input_ids, out_ids)]
    reply = processor.batch_decode(trimmed, skip_special_tokens=True)[0]
    return reply.strip()


def extract_avm_codes(model_reply):
    """Extract AVM-looking codes from Qwen's reply."""
    codes = AVM_CODE_PATTERN.findall(model_reply)
    return codes if codes else [model_reply.replace("\n", " ").strip()]


def save_prediction_lines(lines, output_path):
    """Save prediction lines."""
    output_path.write_text("\n".join(lines) + "\n", encoding="utf-8")


prediction_lines = []

for row_index, row in enumerate(rows[:NUM_SAMPLES_TO_RUN]):
    print(f"Processing {row_index + 1}/{NUM_SAMPLES_TO_RUN}")

    raw_prediction = ask_qwen_avm_codes_no_display(
        row["image"],
        system_prompt=avm_system_prompt,
        max_new_tokens=100,
    )

    predicted_codes = extract_avm_codes(raw_prediction)
    prediction_lines.append(f"{row_index}: {', '.join(predicted_codes)}")

    # Save after each image so progress is not lost if the runtime stops.
    save_prediction_lines(prediction_lines, PREDICTIONS_OUTPUT_PATH)

print(f"Saved {len(prediction_lines)} predictions to {PREDICTIONS_OUTPUT_PATH}")
# Out:
# Processing 1/266
# Processing 2/266
# Processing 3/266
# Processing 4/266
# Processing 5/266
# Processing 6/266
# Processing 7/266
# Processing 8/266
# Processing 9/266
# Processing 10/266
# Processing 11/266
# Processing 12/266
# Processing 13/266
# Processing 14/266
# Processing 15/266
# Processing 16/266
# Processing 17/266
# Processing 18/266
# Processing 19/266
# Processing 20/266
# Processing 21/266
# Processing 22/266
# Processing 23/266
# Processing 24/266
# Processing 25/266
# Processing 26/266
# Processing 27/266
# Processing 28/266
# Processing 29/266
# Processing 30/266
# Processing 31/266
# Processing 32/266
# Processing 33/266
# Processing 34/266
# Processing 35/266
# Processing 36/266
# Processing 37/266
# Processing 38/266
# Processing 39/266
# Processing 40/266
# Processing 41/266
# Processing 42/266
# Processing 43/266
# Processing 44/266
# Processing 45/266
# Processing 46/266
# Processing 47/266
# Processing 48/266
# Processing 49/266
# Processing 50/266
# Processing 51/266
# Processing 52/266
# Processing 53/266
# Processing 54/266
# Processing 55/266
# Processing 56/266
# Processing 57/266
# Processing 58/266
# Processing 59/266
# Processing 60/266
# Processing 61/266
# Processing 62/266
# Processing 63/266
# Processing 64/266
# Processing 65/266
# Processing 66/266
# Processing 67/266
# Processing 68/266
# Processing 69/266
# Processing 70/266
# Processing 71/266
# Processing 72/266
# Processing 73/266
# Processing 74/266
# Processing 75/266
# Processing 76/266
# Processing 77/266
# Processing 78/266
# Processing 79/266
# Processing 80/266
# Processing 81/266
# Processing 82/266
# Processing 83/266
# Processing 84/266
# Processing 85/266
# Processing 86/266
# Processing 87/266
# Processing 88/266
# Processing 89/266
# Processing 90/266
# Processing 91/266
# Processing 92/266
# Processing 93/266
# Processing 94/266
# Processing 95/266
# Processing 96/266
# Processing 97/266
# Processing 98/266
# Processing 99/266
# Processing 100/266
# Processing 101/266
# Processing 102/266
# Processing 103/266
# Processing 104/266
# Processing 105/266
# Processing 106/266
# Processing 107/266
# Processing 108/266
# Processing 109/266
# Processing 110/266
# Processing 111/266
# Processing 112/266
# Processing 113/266
# Processing 114/266
# Processing 115/266
# Processing 116/266
# Processing 117/266
# Processing 118/266
# Processing 119/266
# Processing 120/266
# Processing 121/266
# Processing 122/266
# Processing 123/266
# Processing 124/266
# Processing 125/266
# Processing 126/266
# Processing 127/266
# Processing 128/266
# Processing 129/266
# Processing 130/266
# Processing 131/266
# Processing 132/266
# Processing 133/266
# Processing 134/266
# Processing 135/266
# Processing 136/266
# Processing 137/266
# Processing 138/266
# Processing 139/266
# Processing 140/266
# Processing 141/266
# Processing 142/266
# Processing 143/266
# Processing 144/266
# Processing 145/266
# Processing 146/266
# Processing 147/266
# Processing 148/266
# Processing 149/266
# Processing 150/266
# Processing 151/266
# Processing 152/266
# Processing 153/266
# Processing 154/266
# Processing 155/266
# Processing 156/266
# Processing 157/266
# Processing 158/266
# Processing 159/266
# Processing 160/266
# Processing 161/266
# Processing 162/266
# Processing 163/266
# Processing 164/266
# Processing 165/266
# Processing 166/266
# Processing 167/266
# Processing 168/266
# Processing 169/266
# Processing 170/266
# Processing 171/266
# Processing 172/266
# Processing 173/266
# Processing 174/266
# Processing 175/266
# Processing 176/266
# Processing 177/266
# Processing 178/266
# Processing 179/266
# Processing 180/266
# Processing 181/266
# Processing 182/266
# Processing 183/266
# Processing 184/266
# Processing 185/266
# Processing 186/266
# Processing 187/266
# Processing 188/266
# Processing 189/266
# Processing 190/266
# Processing 191/266
# Processing 192/266
# Processing 193/266
# Processing 194/266
# Processing 195/266
# Processing 196/266
# Processing 197/266
# Processing 198/266
# Processing 199/266
# Processing 200/266
# Processing 201/266
# Processing 202/266
# Processing 203/266
# Processing 204/266
# Processing 205/266
# Processing 206/266
# Processing 207/266
# Processing 208/266
# Processing 209/266
# Processing 210/266
# Processing 211/266
# Processing 212/266
# Processing 213/266
# Processing 214/266
# Processing 215/266
# Processing 216/266
# Processing 217/266
# Processing 218/266
# Processing 219/266
# Processing 220/266
# Processing 221/266
# Processing 222/266
# Processing 223/266
# Processing 224/266
# Processing 225/266
# Processing 226/266
# Processing 227/266
# Processing 228/266
# Processing 229/266
# Processing 230/266
# Processing 231/266
# Processing 232/266
# Processing 233/266
# Processing 234/266
# Processing 235/266
# Processing 236/266
# Processing 237/266
# Processing 238/266
# Processing 239/266
# Processing 240/266
# Processing 241/266
# Processing 242/266
# Processing 243/266
# Processing 244/266
# Processing 245/266
# Processing 246/266
# Processing 247/266
# Processing 248/266
# Processing 249/266
# Processing 250/266
# Processing 251/266
# Processing 252/266
# Processing 253/266
# Processing 254/266
# Processing 255/266
# Processing 256/266
# Processing 257/266
# Processing 258/266
# Processing 259/266
# Processing 260/266
# Processing 261/266
# Processing 262/266
# Processing 263/266
# Processing 264/266
# Processing 265/266
# Processing 266/266
# Saved 266 predictions to qwen_predicted_avm_codes_strict_codes_v1.txt

# %% [markdown]
# #### Qwen output/prediction

# %%
from pathlib import Path


#output the whole thing
print(PREDICTIONS_OUTPUT_PATH.resolve())
print(PREDICTIONS_OUTPUT_PATH.read_text(encoding="utf-8"))#output the whole thing
# Out:
# /content/qwen_predicted_avm_codes_strict_codes_v1.txt
# 0: C.4.1.4
# 1: C.5.1.7
# 2: B.4.1.2
# 3: B.3.5.1.2
# 4: B.4.2.3.1
# 5: C.5.3.2.1
# 6: C.5.1.1
# 7: C.5.5.3
# 8: C.5.1.7
# 9: C.5.1.1
# 10: B.4.1.1, B.3.5.1.2
# 11: C.5.1.7
# 12: C.5.1.1
# 13: C.5.1.1
# 14: C.5.5.3
# 15: C.5.1.7
# 16: C.5.5.4
# 17: C.4.1.4
# 18: B.4.1.4
# 19: C.4.1.4
# 20: C.5.1.7, C.5.5.1
# 21: C.5.1.7
# 22: C.5.1.7
# 23: C.4.1.5
# 24: C.5.1.1
# 25: C.5.1.1
# 26: C.5.1.1
# 27: C.5.1.1
# 28: C.5.1.7
# 29: C.5.1.1
# 30: C.5.1.7, C.5.1.8
# 31: C.5.1.1
# 32: C.5.1.7
# 33: C.4.1.2
# 34: C.4.2.3.1
# 35: C.5.1.1
# 36: C.5.1.7
# 37: C.5.1.1
# 38: C.5.1.1
# 39: C.5.1.1
# 40: C.5.1.1
# 41: C.5.1.7, C.5.5.1
# 42: C.5.1.7
# 43: C.5.1.1
# 44: B.3.6.4.1
# 45: C.5.5.3
# 46: B.4.1.3, B.5.5.1
# 47: B.4.1.3, B.3.5.1.2
# 48: C.5.5.3, B.4.1.1
# 49: C.4.1.4
# 50: B.3.1.3
# 51: C.5.1.7
# 52: B.3.1.3, B.3.3.5
# 53: C.5.5.4
# 54: C.5.1.1, C.5.1.2
# 55: C.5.5.4
# 56: C.4.1.2
# 57: C.3.1.8, C.3.1.9.1, C.3.7.2.1
# 58: B.3.6.4.1
# 59: C.5.1.7
# 60: C.5.1.7
# 61: C.5.1.7
# 62: C.4.1.2
# 63: C.4.1.2
# 64: C.5.1.7
# 65: C.4.1.2
# 66: C.4.1.2, C.3.5.1.2
# 67: C.5.1.7
# 68: C.4.1.2
# 69: B.4.1.4
# 70: C.5.1.1
# 71: C.5.1.7
# 72: C.5.1.1
# 73: C.5.1.7
# 74: C.5.1.1, C.5.1.2, C.5.1.4, C.5.1.6, C.5.5.3
# 75: C.5.1.7
# 76: C.4.1.4
# 77: B.3.1.8, B.3.1.9, B.3.1.9.1, B.3.7.2.1, B.3.7.2.2, B.3.7.3.1, B.3.7.3.2, B.4.1.4, B.4.2.1.1, B.4.2.2.1, B.4.2
# 78: C.5.1.1, C.3.1.3, C.3.1.9.1, C.3.7.2.1
# 79: B.3.5.1.2
# 80: B.4.1.3, B.3.5.1.2, B.3.5.2.1
# 81: B.7.1.3
# 82: B.4.1.2, B.3.1.3, B.3.5.1.2
# 83: B.7.1.4.1
# 84: C.5.4.6
# 85: B.4.1.5, B.4.2.1.1
# 86: C.5.5.3
# 87: B.3.1.3, B.3.5.1.2
# 88: C.4.1.4
# 89: C.4.1.4
# 90: C.4.1.4
# 91: C.4.1.4
# 92: B.4.1.4
# 93: C.4.1.2
# 94: B.4.1.2
# 95: B.7.1.1
# 96: C.4.1.2, C.3.5.1.2
# 97: C.4.1.4
# 98: B.2.2.3.1
# 99: C.4.2.3.1
# 100: C.5.1.1
# 101: C.6.1.3
# 102: C.5.1.7
# 103: C.5.5.3
# 104: C.5.5.4
# 105: C.5.5.3
# 106: B.3.5.1.2, B.3.5.2.1, B.3.5.3.1
# 107: C.5.1.1
# 108: C.4.1.2
# 109: D.5.5.3
# 110: C.5.5.3
# 111: B.7.1.1
# 112: C.5.5.4
# 113: C.5.5.3
# 114: C.5.5.4
# 115: C.5.5.3
# 116: C.5.1.1
# 117: C.5.1.1
# 118: C.5.1.7, C.5.1.1
# 119: B.7.1.1
# 120: C.4.1.2
# 121: C.5.1.7, C.5.5.3
# 122: C.5.5.3
# 123: B.3.1.3, B.3.3.5, B.3.6.1
# 124: C.4.1.4
# 125: C.5.5.4
# 126: D.5.5.3
# 127: C.5.1.1, C.5.1.2, C.5.1.3, C.5.1.4, C.5.1.5, C.5.1.6, C.5.1.7
# 128: C.5.1.7
# 129: C.5.1.7
# 130: C.5.1.1, C.5.5.3
# 131: C.5.5.3
# 132: C.5.1.7, C.5.5.3
# 133: C.5.5.3
# 134: C.4.1.4
# 135: C.4.1.4
# 136: C.4.1.4
# 137: B.3.1.3
# 138: B.3.5.1.2
# 139: C.4.1.2
# 140: B.4.1.2
# 141: C.5.1.1
# 142: C.4.1.2, C.3.1.3
# 143: C.4.1.4
# 144: C.4.1.4
# 145: C.4.1.4
# 146: C.4.1.4
# 147: C.5.1.7, C.3.1.3, C.3.5.1.2
# 148: B.3.5.1.2
# 149: C.5.1.7
# 150: B.3.5.1.2, B.3.5.2.1
# 151: C.4.1.2
# 152: B.4.1.2
# 153: C.4.1.4
# 154: C.5.1.7
# 155: C.4.2.3.1
# 156: C.5.1.7
# 157: C.4.1.4
# 158: C.4.1.2
# 159: C.4.1.4
# 160: C.4.1.2
# 161: C.4.1.4
# 162: C.4.1.4
# 163: B.2.2.3.2
# 164: C.3.5.2.1
# 165: B.2.2.3.2
# 166: A.2.3
# 167: A.1.2.1.1, A.1.2.1.2, A.1.2.1.3, A.1.2.1.4, A.1.2.1.5, A.1.2.1.6, A.1.2.1.7, A.1.4.1.1.1, A.1.4.1.1.2, A.1.4.1.1.3, A.1
# 168: B.3.1.3
# 169: B.3.3.5
# 170: C.2.2.2
# 171: B.2.2.2
# 172: B.2.2.1
# 173: B.2.2.1
# 174: A.1.1.1, A.7.1.4.1
# 175: B.4.1.2
# 176: B.3.1.3, C.5.1.1
# 177: C.5.1.7
# 178: C.5.1.1
# 179: C.5.1.1, C.5.1.2
# 180: C.5.1.4
# 181: C.5.1.7
# 182: D.5.5.3
# 183: C.5.5.4
# 184: C.5.1.1, C.5.1.2, C.5.5.3
# 185: C.5.5.4
# 186: C.4.1.2
# 187: C.4.1.2
# 188: B.3.5.1.2, B.3.5.2.1, B.3.5.3.1
# 189: B.6.2.1
# 190: B.4.1.3, B.4.2.1.1, B.3.5.2.1
# 191: B.4.1.2, B.3.5.1.2, B.3.5.2.1
# 192: C.4.1.4
# 193: B.3.6.4.1, B.3.6.4.2
# 194: C.3.1.8, C.4.1.4
# 195: B.4.1.3
# 196: E.3.5.1.2
# 197: B.6.2.2
# 198: B.6.2.2
# 199: C.4.1.4
# 200: C.4.1.4
# 201: B.3.1.3, B.3.6.1
# 202: B.3.6.4.2
# 203: B.3.5.1.2
# 204: B.3.5.1.2
# 205: B.4.1.2
# 206: C.4.1.2
# 207: B.4.1.2
# 208: B.4.1.2
# 209: C.4.1.2
# 210: C.4.1.2
# 211: C.4.1.2, C.3.5.1.2
# 212: C.4.2.3.1
# 213: C.4.1.2
# 214: C.4.1.2
# 215: C.5.1.7
# 216: C.5.1.1
# 217: C.5.5.4
# 218: C.5.5.3
# 219: C.5.1.7, C.5.5.3, C.5.1.1, C.5.1.4, C.5.1.6, C.5.1.2, C.5.1.3, C.5.4.1, C.5.4.2, C.5.4.3, C.5.4.4, C.5.4.5, C.5
# 220: C.5.1.7
# 221: C.5.1.7
# 222: B.3.1.3
# 223: C.5.5.3
# 224: C.5.1.7
# 225: C.5.5.3
# 226: C.5.1.1, C.5.1.4, C.5.5.3
# 227: B.3.1.3, B.3.6.1, B.5.1.1, B.5.1.2, B.5.5.1
# 228: B.3.6.4.1
# 229: B.3.6.4.1
# 230: B.3.6.4.1
# 231: C.5.1.1
# 232: B.7.1.3
# 233: B.4.1.3, B.3.5.1.2, B.3.5.2.1
# 234: B.4.1.3, B.3.5.1.2, B.3.5.2.1
# 235: C.5.1.7
# 236: C.5.1.1, C.5.1.2, C.5.1.3, C.5.1.4, C.5.1.5, C.5.1.6, C.5.1.7
# 237: C.5.1.7
# 238: C.5.1.7
# 239: D.6.1.3
# 240: B.4.1.2
# 241: B.3.1.3, B.3.3.5, B.7.1.1
# 242: B.3.1.3, B.3.1.4, B.3.1.5, B.3.1.6, B.3.1.7, B.3.1.8, B.3.1.9, B.3.1.10, B.3.2.1, B.3.2.2, B.3.2.3, B.3.2.4, B.3
# 243: C.5.1.1, C.5.1.2, C.5.5.3
# 244: B.2.2.3.1
# 245: B.2.2.3.2
# 246: B.2.2.3.1
# 247: B.2.2.3.1
# 248: B.3.5.1.2, B.3.5.2.1
# 249: C.5.5.4
# 250: C.5.5.4
# 251: B.3.1.3, B.3.3.7, B.3.6.1
# 252: C.5.5.4
# 253: B.4.1.2
# 254: B.4.1.2
# 255: C.5.1.1, C.5.1.2, C.5.1.3, C.5.1.4, C.5.1.5, C.5.1.6, C.5.1.7, C.5.5.1, C.5.5.2, C.5.5.3, C.5.5.4
# 256: C.5.5.3
# 257: C.6.1.1
# 258: C.3.1.3, C.3.1.4, C.3.1.5, C.3.1.6, C.3.1.7, C.3.1.8, C.3.1.9, C.3.1.10, C.3.2.1, C.3.2.2, C.3.2.3, C.3.2.4, C.3
# 259: C.4.1.4
# 260: B.4.1.3, B.4.2.1.1
# 261: C.4.1.4, C.4.1.5, C.4.2.1.1, C.4.2.2.1, C.4.2.3.1, C.4.2.3.2, C.4.2.3.3, C.3.1.8, C.3.1.9.1, C.3.1.9.2, C.3.1
# 262: D.5.5.3
# 263: C.5.5.4
# 264: D.6.1.1
# 265: B.3.1.3, B.3.6.1

# %%
from pathlib import Path
import pandas as pd

qwen_out = PREDICTIONS_OUTPUT_PATH.read_text(encoding="utf-8").splitlines()

#Print each column 1
#print(qwen_out[1])

qwen_codes = []
for line in qwen_out:
    _, codes_text = line.split(":", 1)
    codes = [code.strip() for code in codes_text.split(",") if code.strip()]
    qwen_codes.append(codes)


count = 0

for i in range(len(qwen_codes)):
   if(qwen_codes[i] == TRUE_AVM_CODES[i]):
       count = count + 1

print("qwen got correct: " + str(count))
# Out:
# qwen got correct: 12

# %% [markdown]
# #### Metrics Calculation
#
#  Compare Qwen AVM-code predictions against `TRUE_AVM_CODES`.

# %%
from pathlib import Path
import re
import pandas as pd

AVM_CODE_PATTERN = re.compile(r"\b[A-EX]\.\d+(?:\.\d+)*\b")


def parse_prediction_file(output_path):
    """Read Qwen predictions from `index: code, code` text format."""
    predictions = {}

    for line in output_path.read_text(encoding="utf-8").splitlines():
        line = line.strip()
        if not line or ":" not in line:
            continue

        row_text, prediction_text = line.split(":", 1)
        row_index = int(row_text.strip())
        codes = AVM_CODE_PATTERN.findall(prediction_text)
        predictions[row_index] = codes

    return predictions


def precision_recall_f1(predicted_codes, true_codes):
    """Calculate set precision, recall, and F1 for one image."""
    predicted_set = set(predicted_codes)
    true_set = set(true_codes)

    if not predicted_set and not true_set:
        return 1.0, 1.0, 1.0
    if not predicted_set:
        return 0.0, 0.0, 0.0
    if not true_set:
        return 0.0, 0.0, 0.0

    correct = len(predicted_set & true_set)
    precision = correct / len(predicted_set)
    recall = correct / len(true_set)
    f1 = 0.0 if precision + recall == 0 else 2 * precision * recall / (precision + recall)
    return precision, recall, f1


def code_ancestors(code):
    """Return the AVM hierarchy path for one code, including the code itself."""
    parts = code.split(".")
    ancestors = []

    for end in range(1, len(parts) + 1):
        ancestors.append(".".join(parts[:end]))

    return ancestors


def expand_with_ancestors(codes):
    """Expand codes into a set containing each code and all of its ancestors."""
    expanded = set()

    for code in codes:
        expanded.update(code_ancestors(code))

    return expanded


qwen_predictions = parse_prediction_file(PREDICTIONS_OUTPUT_PATH)
row_count = min(len(TRUE_AVM_CODES), len(qwen_predictions))

metric_rows = []

for row_index in range(row_count):
    true_codes = TRUE_AVM_CODES[row_index]
    predicted_codes = qwen_predictions.get(row_index, [])

    precision, recall, f1 = precision_recall_f1(predicted_codes, true_codes)

    hierarchical_predicted = expand_with_ancestors(predicted_codes)
    hierarchical_true = expand_with_ancestors(true_codes)
    h_precision, h_recall, h_f1 = precision_recall_f1(hierarchical_predicted, hierarchical_true)

    metric_rows.append({
        "row_index": row_index,
        "predicted_codes": predicted_codes,
        "true_codes": true_codes,
        "exact_set_match": set(predicted_codes) == set(true_codes),
        "over_predicted": len(predicted_codes) > len(true_codes),
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "hierarchical_precision": h_precision,
        "hierarchical_recall": h_recall,
        "hierarchical_f1": h_f1,
    })

metrics_df = pd.DataFrame(metric_rows)

exact_match_count = int(metrics_df["exact_set_match"].sum())
exact_match_rate = metrics_df["exact_set_match"].mean()
over_prediction_count = int(metrics_df["over_predicted"].sum())

summary = {
    "rows_evaluated": row_count,
    "exact_set_matches": exact_match_count,
    "exact_match_rate": exact_match_rate,
    "macro_precision": metrics_df["precision"].mean(),
    "macro_recall": metrics_df["recall"].mean(),
    "macro_f1": metrics_df["f1"].mean(),
    "over_prediction_rows": over_prediction_count,
    "macro_hierarchical_precision": metrics_df["hierarchical_precision"].mean(),
    "macro_hierarchical_recall": metrics_df["hierarchical_recall"].mean(),
    "macro_hierarchical_f1": metrics_df["hierarchical_f1"].mean(),
}

print("Metric 1 — Exact Set Match")
print(f"Exact matches: {summary['exact_set_matches']} / {summary['rows_evaluated']}")
print(f"Exact match rate: {summary['exact_match_rate']:.4f}")

print("\nMetric 2 — Macro-averaged Standard F1")
print(f"Precision: {summary['macro_precision']:.4f}")
print(f"Recall:    {summary['macro_recall']:.4f}")
print(f"F1:        {summary['macro_f1']:.4f}")
print(f"Over-prediction rows: {summary['over_prediction_rows']}")

print("\nMetric 3 — Macro-averaged Hierarchical F1")
print(f"Hierarchical Precision: {summary['macro_hierarchical_precision']:.4f}")
print(f"Hierarchical Recall:    {summary['macro_hierarchical_recall']:.4f}")
print(f"Hierarchical F1:        {summary['macro_hierarchical_f1']:.4f}")

metrics_df.head()
# Out:
# Metric 1 — Exact Set Match
# Exact matches: 12 / 266
# Exact match rate: 0.0451
#
# Metric 2 — Macro-averaged Standard F1
# Precision: 0.0955
# Recall:    0.1667
# F1:        0.1122
# Over-prediction rows: 142
#
# Metric 3 — Macro-averaged Hierarchical F1
# Hierarchical Precision: 0.2428
# Hierarchical Recall:    0.2906
# Hierarchical F1:        0.2553
#    row_index                                    predicted_codes  \
# 0          0                                          [C.5.1.7]
# 1          1                                 [C.5.1.7, C.5.1.8]
# 2          2                                          [B.4.1.3]
# 3          3                                 [C.5.1.1, C.5.1.2]
# 4          4  [B.5.1.1, B.5.1.2, B.5.1.3, B.5.1.4, B.5.1.5, ...
#
#              true_codes  exact_set_match  over_predicted  precision  recall  \
# 0  [B.3.6.4.1, B.4.1.3]            False           False        0.0     0.0
# 1             [C.5.1.7]            False            True        0.5     1.0
# 2             [C.4.1.2]            False           False        0.0     0.0
# 3             [D.6.2.2]            False            True        0.0     0.0
# 4             [C.3.2.1]            False            True        0.0     0.0
#
#          f1  hierarchical_precision  hierarchical_recall  hierarchical_f1
# 0  0.000000                     0.0                  0.0         0.000000
# 1  0.666667                     0.8                  1.0         0.888889
# 2  0.000000                     0.0                  0.0         0.000000
# 3  0.000000                     0.0                  0.0         0.000000
# 4  0.000000                     0.0                  0.0         0.000000
